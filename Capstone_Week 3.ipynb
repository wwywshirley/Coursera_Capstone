# %% [markdown]
# # Part 1

# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup # library to parse HTML and XML documents

# %% [markdown]
# ## Get data

# %%
data = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %%
soup = BeautifulSoup(data, 'html.parser')

# %%
postalCodeList = []
boroughList = []
neighborhoodList = []

# %%
# find the table
soup.find('table').find_all('tr')

# find all the rows of the table
soup.find('table').find_all('tr')

# for each row of the table, find all the table data
for row in soup.find('table').find_all('tr'):
    cells = row.find_all('td')

# %%
for row in soup.find('table').find_all('tr'):
    cells = row.find_all('td')
    if(len(cells) > 0):
        postalCodeList.append(cells[0].text)
        boroughList.append(cells[1].text)
        neighborhoodList.append(cells[2].text.rstrip('\n')) # avoid new lines in neighborhood cell

# %%
toronto_df = pd.DataFrame({"PostalCode": postalCodeList,
                           "Borough": boroughList,
                           "Neighborhood": neighborhoodList})

toronto_df.head()
# Out:
#   PostalCode             Borough               Neighborhood
# 0      M1A\n      Not assigned\n               Not assigned
# 1      M2A\n      Not assigned\n               Not assigned
# 2      M3A\n        North York\n                  Parkwoods
# 3      M4A\n        North York\n           Victoria Village
# 4      M5A\n  Downtown Toronto\n  Regent Park, Harbourfront

# %%
toronto_df["PostalCode"] = toronto_df["PostalCode"].str.replace("\n","")
toronto_df["Borough"] = toronto_df["Borough"].str.replace("\n","")

# %% [markdown]
# ## Drop 'Not assigned'

# %%
toronto_df_dropna = toronto_df[toronto_df.Neighborhood != "Not assigned"].reset_index(drop=True)
toronto_df_dropna.head()
# Out:
#   PostalCode           Borough                                 Neighborhood
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# ## Group neighborhoods

# %%
toronto_df_grouped = toronto_df_dropna.groupby(["PostalCode", "Borough"], as_index=False).agg(lambda x: ", ".join(x))
toronto_df_grouped.head()
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Malvern, Rouge
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
for index, row in toronto_df_grouped.iterrows():
    if row["Neighborhood"] == "Not assigned":
        row["Neighborhood"] = row["Borough"]
        
toronto_df_grouped.head()
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Malvern, Rouge
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
# create a new test dataframe
column_names = ["PostalCode", "Borough", "Neighborhood"]
test_df = pd.DataFrame(columns=column_names)

test_list = ["M5G", "M2H", "M4B", "M1J", "M4G", "M4M", "M1R", "M9V", "M9L", "M5V", "M1B", "M5A"]

for postcode in test_list:
    test_df = test_df.append(toronto_df_grouped[toronto_df_grouped["PostalCode"]==postcode], ignore_index=True)
    
test_df
# Out:
#    PostalCode           Borough  \
# 0         M5G  Downtown Toronto
# 1         M2H        North York
# 2         M4B         East York
# 3         M1J       Scarborough
# 4         M4G         East York
# 5         M4M      East Toronto
# 6         M1R       Scarborough
# 7         M9V         Etobicoke
# 8         M9L        North York
# 9         M5V  Downtown Toronto
# 10        M1B       Scarborough
# 11        M5A  Downtown Toronto
#
#                                          Neighborhood
# 0                                  Central Bay Street
# 1                                   Hillcrest Village
# 2                     Parkview Hill, Woodbine Gardens
# 3                                 Scarborough Village
# 4                                             Leaside
# 5                                     Studio District
# 6                                   Wexford, Maryvale
# 7   South Steeles, Silverstone, Humbergate, Jamest...
# 8                                       Humber Summit
# 9   CN Tower, King and Spadina, Railway Lands, Har...
# 10                                     Malvern, Rouge
# 11                          Regent Park, Harbourfront

# %% [markdown]
# ## Print dataframe

# %%
toronto_df_grouped.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part 2

# %% [markdown]
# ## Read Geo Data

# %%
coordinates = pd.read_csv(r"C:\Users\weiyi\Downloads\Geospatial_Coordinates.csv")
coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
coordinates.rename(columns={"Postal Code": "PostalCode"}, inplace=True)
coordinates.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %% [markdown]
# ## Merge tables

# %%
toronto_df_new = toronto_df_grouped.merge(coordinates, on="PostalCode", how="left")
toronto_df_new.head()
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.806686
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
column_names = ["PostalCode", "Borough", "Neighborhood", "Latitude", "Longitude"]
test_df = pd.DataFrame(columns=column_names)

test_list = ["M5G", "M2H", "M4B", "M1J", "M4G", "M4M", "M1R", "M9V", "M9L", "M5V", "M1B", "M5A"]

for postcode in test_list:
    test_df = test_df.append(toronto_df_new[toronto_df_new["PostalCode"]==postcode], ignore_index=True)
    
test_df
# Out:
#    PostalCode           Borough  \
# 0         M5G  Downtown Toronto
# 1         M2H        North York
# 2         M4B         East York
# 3         M1J       Scarborough
# 4         M4G         East York
# 5         M4M      East Toronto
# 6         M1R       Scarborough
# 7         M9V         Etobicoke
# 8         M9L        North York
# 9         M5V  Downtown Toronto
# 10        M1B       Scarborough
# 11        M5A  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                                  Central Bay Street  43.657952 -79.387383
# 1                                   Hillcrest Village  43.803762 -79.363452
# 2                     Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 3                                 Scarborough Village  43.744734 -79.239476
# 4                                             Leaside  43.709060 -79.363452
# 5                                     Studio District  43.659526 -79.340923
# 6                                   Wexford, Maryvale  43.750072 -79.295849
# 7   South Steeles, Silverstone, Humbergate, Jamest...  43.739416 -79.588437
# 8                                       Humber Summit  43.756303 -79.565963
# 9   CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 10                                     Malvern, Rouge  43.806686 -79.194353
# 11                          Regent Park, Harbourfront  43.654260 -79.360636

# %% [markdown]
# # Part 3

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working...
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2019.07=py37_0
#   - defaults/win-64::numba==0.44.1=py37hf9181ef_0
# done
#
# ## Package Plan ##
#
#   environment location: C:\AAApps\Anacondo
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py37_0           6 KB
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     anaconda-custom            |           py37_1           3 KB
#     argh-0.26.2                |  pyh9f0ad1d_1002          26 KB  conda-forge
#     autopep8-1.5.2             |     pyh9f0ad1d_0          39 KB  conda-forge
#     bcrypt-3.1.7               |   py37h8055547_1          40 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py37hfa6e2cd_1000         356 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         184 KB  conda-forge
#     certifi-2020.6.20          |   py37hc8dfbb8_0         151 KB  conda-forge
#     conda-4.8.3                |   py37hc8dfbb8_1         3.1 MB  conda-forge
#     diff-match-patch-20200713  |     pyh9f0ad1d_0          38 KB  conda-forge
#     flake8-3.7.9               |   py37hc8dfbb8_1         147 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     fsspec-0.8.0               |             py_0          61 KB  conda-forge
#     gmpy2-2.1.0b1              |   py37h7db29ea_0         182 KB  conda-forge
#     importlib-metadata-1.7.0   |   py37hc8dfbb8_0          45 KB  conda-forge
#     intervaltree-3.0.2         |             py_0          23 KB  conda-forge
#     libllvm9-9.0.1             |       h21ff451_0          47 KB  conda-forge
#     libspatialindex-1.9.3      |       he025d50_3         380 KB  conda-forge
#     matplotlib-base-3.2.1      |   py37h911224e_0         7.1 MB  conda-forge
#     mpc-1.1.0                  |    h9e20aa4_1006         304 KB  conda-forge
#     mpfr-4.0.2                 |       h2fa13f4_0         1.9 MB  conda-forge
#     mpir-3.0.0                 |    he025d50_1002         3.0 MB  conda-forge
#     openssl-1.1.1f             |       hfa6e2cd_0         4.7 MB  conda-forge
#     paramiko-2.7.1             |     pyh9f0ad1d_1         135 KB  conda-forge
#     path-15.0.0                |   py37hc8dfbb8_0          37 KB  conda-forge
#     pathtools-0.1.2            |             py_1           8 KB  conda-forge
#     pexpect-4.8.0              |   py37hc8dfbb8_1          79 KB  conda-forge
#     prompt-toolkit-3.0.5       |             py_0         232 KB  conda-forge
#     pydocstyle-5.0.2           |             py_0          32 KB  conda-forge
#     pynacl-1.3.0               |py37h2fa13f4_1001         1.4 MB  conda-forge
#     python-jsonrpc-server-0.3.4|             py_0          11 KB  conda-forge
#     python-language-server-0.28.1|           py37_0          75 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     pywin32-ctypes-0.2.0       |py37hc8dfbb8_1001          38 KB  conda-forge
#     qdarkstyle-2.8.1           |     pyh9f0ad1d_0         154 KB  conda-forge
#     regex-2020.4.4             |   py37h8055547_0         336 KB  conda-forge
#     rtree-0.9.4                |   py37h804a536_1          43 KB  conda-forge
#     tbb-2020.1                 |       he980bc4_0         167 KB  conda-forge
#     threadpoolctl-2.1.0        |     pyh5ca1d4c_0          15 KB  conda-forge
#     toml-0.10.1                |     pyh9f0ad1d_0          18 KB  conda-forge
#     typed-ast-1.4.1            |   py37hfa6e2cd_0         148 KB  conda-forge
#     typing_extensions-3.7.4.2  |             py_0          25 KB  conda-forge
#     ujson-2.0.3                |   py37h63f7a3c_0          48 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     watchdog-0.10.3            |   py37hc8dfbb8_1         109 KB  conda-forge
#     yapf-0.30.0                |     pyh9f0ad1d_0         124 KB  conda-forge
#     zope-1.0                   |           py37_1           4 KB
#     zope.event-4.4             |     pyh9f0ad1d_0           9 KB  conda-forge
#     zope.interface-5.1.0       |   py37h8055547_0         293 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        26.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2020.07-py37_0
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   argh               conda-forge/noarch::argh-0.26.2-pyh9f0ad1d_1002
#   autopep8           conda-forge/noarch::autopep8-1.5.2-pyh9f0ad1d_0
#   bcrypt             conda-forge/win-64::bcrypt-3.1.7-py37h8055547_1
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/win-64::brotlipy-0.7.0-py37hfa6e2cd_1000
#   diff-match-patch   conda-forge/noarch::diff-match-patch-20200713-pyh9f0ad1d_0
#   flake8             conda-forge/win-64::flake8-3.7.9-py37hc8dfbb8_1
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   fsspec             conda-forge/noarch::fsspec-0.8.0-py_0
#   gmpy2              conda-forge/win-64::gmpy2-2.1.0b1-py37h7db29ea_0
#   importlib-metadata conda-forge/win-64::importlib-metadata-1.7.0-py37hc8dfbb8_0
#   intervaltree       conda-forge/noarch::intervaltree-3.0.2-py_0
#   libllvm9           conda-forge/win-64::libllvm9-9.0.1-h21ff451_0
#   libspatialindex    conda-forge/win-64::libspatialindex-1.9.3-he025d50_3
#   matplotlib-base    conda-forge/win-64::matplotlib-base-3.2.1-py37h911224e_0
#   mpc                conda-forge/win-64::mpc-1.1.0-h9e20aa4_1006
#   mpfr               conda-forge/win-64::mpfr-4.0.2-h2fa13f4_0
#   mpir               conda-forge/win-64::mpir-3.0.0-he025d50_1002
#   paramiko           conda-forge/noarch::paramiko-2.7.1-pyh9f0ad1d_1
#   path               conda-forge/win-64::path-15.0.0-py37hc8dfbb8_0
#   pathtools          conda-forge/noarch::pathtools-0.1.2-py_1
#   pexpect            conda-forge/win-64::pexpect-4.8.0-py37hc8dfbb8_1
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.0.5-py_0
#   pydocstyle         conda-forge/noarch::pydocstyle-5.0.2-py_0
#   pynacl             conda-forge/win-64::pynacl-1.3.0-py37h2fa13f4_1001
#   python-jsonrpc-se~ conda-forge/noarch::python-jsonrpc-server-0.3.4-py_0
#   python-language-s~ conda-forge/win-64::python-language-server-0.28.1-py37_0
#   python_abi         conda-forge/win-64::python_abi-3.7-1_cp37m
#   pywin32-ctypes     conda-forge/win-64::pywin32-ctypes-0.2.0-py37hc8dfbb8_1001
#   qdarkstyle         conda-forge/noarch::qdarkstyle-2.8.1-pyh9f0ad1d_0
#   regex              conda-forge/win-64::regex-2020.4.4-py37h8055547_0
#   rtree              conda-forge/win-64::rtree-0.9.4-py37h804a536_1
#   tbb                conda-forge/win-64::tbb-2020.1-he980bc4_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-2.1.0-pyh5ca1d4c_0
#   toml               conda-forge/noarch::toml-0.10.1-pyh9f0ad1d_0
#   typed-ast          conda-forge/win-64::typed-ast-1.4.1-py37hfa6e2cd_0
#   typing_extensions  conda-forge/noarch::typing_extensions-3.7.4.2-py_0
#   ujson              conda-forge/win-64::ujson-2.0.3-py37h63f7a3c_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#   watchdog           conda-forge/win-64::watchdog-0.10.3-py37hc8dfbb8_1
#   yapf               conda-forge/noarch::yapf-0.30.0-pyh9f0ad1d_0
#   zope               pkgs/main/win-64::zope-1.0-py37_1
#   zope.event         conda-forge/noarch::zope.event-4.4-pyh9f0ad1d_0
#   zope.interface     conda-forge/win-64::zope.interface-5.1.0-py37h8055547_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2019.5.15-0 --> conda-forge::ca-certificates-2020.6.20-hecda079_0
#   certifi               pkgs/main::certifi-2019.6.16-py37_0 --> conda-forge::certifi-2020.6.20-py37hc8dfbb8_0
#   conda                       pkgs/main::conda-4.8.3-py37_0 --> conda-forge::conda-4.8.3-py37hc8dfbb8_1
#   openssl              pkgs/main::openssl-1.1.1c-he774522_1 --> conda-forge::openssl-1.1.1f-hfa6e2cd_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2019.07-py37_0 --> custom-py37_1
#
#
#
# Downloading and Extracting Packages
#
# typed-ast-1.4.1      | 148 KB    |            |   0%
# typed-ast-1.4.1      | 148 KB    | ########## | 100%
#
# paramiko-2.7.1       | 135 KB    |            |   0%
# paramiko-2.7.1       | 135 KB    | ########## | 100%
#
# pathtools-0.1.2      | 8 KB      |            |   0%
# pathtools-0.1.2      | 8 KB      | ########## | 100%
#
# mpir-3.0.0           | 3.0 MB    |            |   0%
# mpir-3.0.0           | 3.0 MB    | ##8        |  28%
# mpir-3.0.0           | 3.0 MB    | ######5    |  66%
# mpir-3.0.0           | 3.0 MB    | ########## | 100%
#
# folium-0.5.0         | 45 KB     |            |   0%
# folium-0.5.0         | 45 KB     | ########## | 100%
#
# vincent-0.4.4        | 28 KB     |            |   0%
# vincent-0.4.4        | 28 KB     | ########## | 100%
#
# zope-1.0             | 4 KB      |            |   0%
# zope-1.0             | 4 KB      | ########## | 100%
#
# libllvm9-9.0.1       | 47 KB     |            |   0%
# libllvm9-9.0.1       | 47 KB     | ########## | 100%
#
# fsspec-0.8.0         | 61 KB     |            |   0%
# fsspec-0.8.0         | 61 KB     | ########## | 100%
#
# mpfr-4.0.2           | 1.9 MB    |            |   0%
# mpfr-4.0.2           | 1.9 MB    | ####1      |  41%
# mpfr-4.0.2           | 1.9 MB    | ########## | 100%
#
# python-jsonrpc-serve | 11 KB     |            |   0%
# python-jsonrpc-serve | 11 KB     | ########## | 100%
#
# openssl-1.1.1f       | 4.7 MB    |            |   0%
# openssl-1.1.1f       | 4.7 MB    | #6         |  17%
# openssl-1.1.1f       | 4.7 MB    | ####       |  41%
# openssl-1.1.1f       | 4.7 MB    | ######4    |  65%
# openssl-1.1.1f       | 4.7 MB    | ########9  |  89%
# openssl-1.1.1f       | 4.7 MB    | ########## | 100%
#
# conda-4.8.3          | 3.1 MB    |            |   0%
# conda-4.8.3          | 3.1 MB    | ##8        |  29%
# conda-4.8.3          | 3.1 MB    | ######5    |  66%
# conda-4.8.3          | 3.1 MB    | ########## | 100%
#
# python-language-serv | 75 KB     |            |   0%
# python-language-serv | 75 KB     | ########## | 100%
#
# yapf-0.30.0          | 124 KB    |            |   0%
# yapf-0.30.0          | 124 KB    | ########## | 100%
#
# path-15.0.0          | 37 KB     |            |   0%
# path-15.0.0          | 37 KB     | ########## | 100%
#
# pywin32-ctypes-0.2.0 | 38 KB     |            |   0%
# pywin32-ctypes-0.2.0 | 38 KB     | ########## | 100%
#
# altair-4.1.0         | 614 KB    |            |   0%
# altair-4.1.0         | 614 KB    | #######5   |  76%
# altair-4.1.0         | 614 KB    | ########## | 100%
#
# autopep8-1.5.2       | 39 KB     |            |   0%
# autopep8-1.5.2       | 39 KB     | ########## | 100%
#
# gmpy2-2.1.0b1        | 182 KB    |            |   0%
# gmpy2-2.1.0b1        | 182 KB    | ########## | 100%
#
# mpc-1.1.0            | 304 KB    |            |   0%
# mpc-1.1.0            | 304 KB    | ########## | 100%
#
# ca-certificates-2020 | 184 KB    |            |   0%
# ca-certificates-2020 | 184 KB    | ########## | 100%
#
# flake8-3.7.9         | 147 KB    |            |   0%
# flake8-3.7.9         | 147 KB    | ########## | 100%
#
# matplotlib-base-3.2. | 7.1 MB    |            |   0%
# matplotlib-base-3.2. | 7.1 MB    | #          |  10%
# matplotlib-base-3.2. | 7.1 MB    | ##6        |  26%
# matplotlib-base-3.2. | 7.1 MB    | ####2      |  42%
# matplotlib-base-3.2. | 7.1 MB    | #####7     |  58%
# matplotlib-base-3.2. | 7.1 MB    | #######3   |  74%
# matplotlib-base-3.2. | 7.1 MB    | ########9  |  90%
# matplotlib-base-3.2. | 7.1 MB    | ########## | 100%
#
# branca-0.4.1         | 26 KB     |            |   0%
# branca-0.4.1         | 26 KB     | ########## | 100%
#
# libspatialindex-1.9. | 380 KB    |            |   0%
# libspatialindex-1.9. | 380 KB    | ########## | 100%
#
# ujson-2.0.3          | 48 KB     |            |   0%
# ujson-2.0.3          | 48 KB     | ########## | 100%
#
# zope.event-4.4       | 9 KB      |            |   0%
# zope.event-4.4       | 9 KB      | ########## | 100%
#
# prompt-toolkit-3.0.5 | 232 KB    |            |   0%
# prompt-toolkit-3.0.5 | 232 KB    | ########## | 100%
#
# _anaconda_depends-20 | 6 KB      |            |   0%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
#
# qdarkstyle-2.8.1     | 154 KB    |            |   0%
# qdarkstyle-2.8.1     | 154 KB    | ########## | 100%
#
# tbb-2020.1           | 167 KB    |            |   0%
# tbb-2020.1           | 167 KB    | ########## | 100%
#
# argh-0.26.2          | 26 KB     |            |   0%
# argh-0.26.2          | 26 KB     | ########## | 100%
#
# pydocstyle-5.0.2     | 32 KB     |            |   0%
# pydocstyle-5.0.2     | 32 KB     | ########## | 100%
#
# importlib-metadata-1 | 45 KB     |            |   0%
# importlib-metadata-1 | 45 KB     | ########## | 100%
#
# diff-match-patch-202 | 38 KB     |            |   0%
# diff-match-patch-202 | 38 KB     | ########## | 100%
#
# threadpoolctl-2.1.0  | 15 KB     |            |   0%
# threadpoolctl-2.1.0  | 15 KB     | ########## | 100%
#
# zope.interface-5.1.0 | 293 KB    |            |   0%
# zope.interface-5.1.0 | 293 KB    | ########## | 100%
#
# rtree-0.9.4          | 43 KB     |            |   0%
# rtree-0.9.4          | 43 KB     | ########## | 100%
#
# intervaltree-3.0.2   | 23 KB     |            |   0%
# intervaltree-3.0.2   | 23 KB     | ########## | 100%
#
# regex-2020.4.4       | 336 KB    |            |   0%
# regex-2020.4.4       | 336 KB    | ########## | 100%
#
# toml-0.10.1          | 18 KB     |            |   0%
# toml-0.10.1          | 18 KB     | ########## | 100%
#
# python_abi-3.7       | 4 KB      |            |   0%
# python_abi-3.7       | 4 KB      | ########## | 100%
#
# certifi-2020.6.20    | 151 KB    |            |   0%
# certifi-2020.6.20    | 151 KB    | ########## | 100%
#
# brotlipy-0.7.0       | 356 KB    |            |   0%
# brotlipy-0.7.0       | 356 KB    | ########## | 100%
#
# bcrypt-3.1.7         | 40 KB     |            |   0%
# bcrypt-3.1.7         | 40 KB     | ########## | 100%
#
# typing_extensions-3. | 25 KB     |            |   0%
# typing_extensions-3. | 25 KB     | ########## | 100%
#
# watchdog-0.10.3      | 109 KB    |            |   0%
# watchdog-0.10.3      | 109 KB    | ########## | 100%
#
# pexpect-4.8.0        | 79 KB     |            |   0%
# pexpect-4.8.0        | 79 KB     | ########## | 100%
#
# anaconda-custom      | 3 KB      |            |   0%
# anaconda-custom      | 3 KB      | ########## | 100%
#
# pynacl-1.3.0         | 1.4 MB    |            |   0%
# pynacl-1.3.0         | 1.4 MB    | ###8       |  38%
# pynacl-1.3.0         | 1.4 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\AAApps\Anacondo
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
#
# geopy-2.0.0          | 63 KB     |            |   0%
# geopy-2.0.0          | 63 KB     | ##5        |  25%
# geopy-2.0.0          | 63 KB     | ########## | 100%
#
# geographiclib-1.50   | 34 KB     |            |   0%
# geographiclib-1.50   | 34 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
from geopy.geocoders import Nominatim

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(test_df['Latitude'], test_df['Longitude'], test_df['Borough'], test_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
